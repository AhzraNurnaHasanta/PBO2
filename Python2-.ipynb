# %%
class lingkaran:
  def __init__(self, jari_jari):
    self.jari_jari = jari_jari

def main():
  obj = lingkaran

  obj.jari_jari = 7

  keliling = 2 * 3.14 * obj.jari_jari

  print("Keliling Lingkaran : ", keliling)

if __name__ == '__main__':
  main()
# Out:
# Keliling Lingkaran :  43.96
